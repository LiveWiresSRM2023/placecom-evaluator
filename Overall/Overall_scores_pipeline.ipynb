# %%
import pandas as pd

df = pd.read_excel("/content/transcripts.xlsx")

# %%
df.head()
# Out:
#                                File Name  \
# 0             ANUSHA S (RA2332008010011)
# 1       DHANUSHYA RAMU (RA2332016010022)
# 2         Vandhana Balasubramanian _2610
# 3  THIRUPURASUNDHARI P (RA2332016010008)
# 4      SOUMILI CHANDRA (RA2332241010163)
#
#                                           Transcript  Score
# 0  Hi everyone. Thank you for giving this opportu...   3.29
# 1  Hi. Hello everyone. Myself Dhanushyar from Dha...   3.37
# 2  Hello everyone. Myself, Bandana. I'm from Birt...   3.46
# 3  Hello everyone. Myself, I am with Ankur Shinwa...   3.68
# 4  Good morning sir. I am Shomindi Chandra from s...   6.52

# %%
key = pd.read_excel("/content/keywords.xlsx")

# %%
keywords = key['Keywords'].to_list()

# %%
# prompt: Using dataframe df: use this transcriipt colomuns to check the relevance of information realted to a particulat list of words using embedinngs and cosine similarity and givethe score out of 10 for  each transcripts in new column usinbg transformers bge-3-small-en-v1.5 model

from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

# Assuming you have a list of relevant words
relevant_words = keywords

# Load the BGE-small-en-v1.5 model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('BAAI/bge-small-en-v1.5')
model = AutoModel.from_pretrained('BAAI/bge-small-en-v1.5')

# Function to calculate cosine similarity
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# Function to calculate relevance score
def calculate_relevance_score(transcript, relevant_words):
    # Tokenize the transcript and relevant words
    # Moved 'return_tokens' argument to __call__ method
    transcript_tokens = tokenizer(transcript, return_tensors='pt', truncation=True, padding=True)
    relevant_word_tokens = tokenizer(relevant_words, return_tensors='pt', truncation=True, padding=True)

    # Get embeddings for the transcript and relevant words
    with torch.no_grad():
        transcript_embedding = model(**transcript_tokens).pooler_output
        relevant_word_embeddings = model(**relevant_word_tokens).pooler_output

    # Calculate the average cosine similarity between the transcript and relevant words
    similarities = [cosine_similarity(transcript_embedding.numpy().flatten(), word_embedding.numpy().flatten()) for word_embedding in relevant_word_embeddings]
    average_similarity = np.mean(similarities)

    # Scale the similarity to a score out of 10
    score = average_similarity * 10
    return score

# Calculate relevance scores for each transcript
df['Relevance Score'] = df['Transcript'].apply(lambda x: calculate_relevance_score(x, relevant_words))

print(df)
# Out:
#                                             File Name  \
# 0                          ANUSHA S (RA2332008010011)
# 1                    DHANUSHYA RAMU (RA2332016010022)
# 2                      Vandhana Balasubramanian _2610
# 3               THIRUPURASUNDHARI P (RA2332016010008)
# 4                   SOUMILI CHANDRA (RA2332241010163)
# 5                 NIRMALRAJ M MOHAN (RA2332241010085)
# 6                       NAVAL AHMED (RA2332016010009)
# 7                   PRIYANKA MANDAL (RA2231202010016)
# 8                         ABISHEK R (RA2332241010021)
# 9          PURUCHOTHAMAN VENKATESAN (RA2332016010011)
# 10                          DEEPA R (RA2332016010015)
# 11                     SHAKTHIVEL R (RA2332016010013)
# 12                  MOHANA MURALI E (RA2332016010006)
# 13                     NIKIL PAUL S (RA2332014010082)
# 14          VIJAYALAKSHMI SUBRAMANI (RA2332241010048)
# 15                     MANIKANDAN D (RA2231241010071)
# 16                          DIVYA K (RA2332014010216)
# 17                  MUHAMMED RISHAN (RA2332016010004)
# 18                   SARAH MARIEM.A (RA2332016010026)
# 19                     M. SHALINI M (RA2231011010017)
# 20                                        Mohan kumar
# 21  B SRI DHARSHINI B SRI DHARSHINI (RA2231203010067)
# 22                    PRARTHANA S R (RA2332016010005)
# 23              VIKRAM MUTHIRULANDI (RA2332016010021)
# 24                        PRAKASH M (RA2332014010115)
# 25                         ANITHA K (RA2332008010017)
hello everyone. Myself, I am with Ankur Shinwa...         5.018086
# 4   Good morning sir. I am Shomindi Chandra from s...         4.939860
# 5   My name is Nimal Raj. I am from Pondicherry. I...         5.103485
# 6   Hi. Myself, Kawalakman. I'm currently pursuing...         5.329919
# 7   Hello everyone, my name is Priyanka Mandu curr...         5.167671
# 8   Good morning everyone. I thank everyone for gi...         5.519792
# 9   My name is Vibhu Shu Taman. I am currently pur...         5.302228
# 10  Hi there. My name is Artipa. I'm currently pur...         4.969367
# 11  Good morning. First of all, thank you for givi...         5.209697
# 12  Hi. Good morning. Thank you for giving me oppo...         5.251795
# 13  Hello everyone, this is Nikhil and I'm from MS...         5.460150
# 14  Good morning. I'm Vijay. Lakshmi. So I'm curre...         5.287257
# 15  Hi, I am Manikandan. I am from Thiruvana, Mala...         4.971960
# 16  Good morning myself Dubya and I am from Vendri...         5.272189
# 17  Hello. Myself, Mohammed Alyshan, and I am curr...         5.480037
# 18  I'm Sara Madame a pursuing MSC biochemistry. I...         4.904784
# 19  Good morning sir or madam. I am Shalini. I am ...         5.096517
# 20  Hi, my name is. I have completed my UG degree ...         5.266097
# 21  Good evening ma'am. First of all thank you for...         5.139318
# 22  Hi, I'm Sr. Prathana. I did my UG in food proc...         5.066540
# 23  Hello there. My name is Vikram. Currently purs...         5.321141
# 24  Thank you for giving this opportunity. My name...         5.382620
# 25  Thank you ma'am for giving me this wonderful o...         5.159461
# 26  Hello. I am Raghavi from the Department of Com...         5.017408
# 27  Sir. First of all thank you for giving me this...         5.066341
# 28  Good morning sir. My name is Aar Bhavadani. I ...         5.424088
# 29  Hello. Myself deepthika. Currently I am pursui...         4.939914
# 30  Hello. My name is Hashm Kubar. I'm currently p...         5.338137
# 31  Hello ma'am. I am Inod. I am pursuing my postg...         5.544291
# 32  Good morning sir. Thank you for giving me oppo...         5.097718
# 33  I did my UG degree in biochemistry at Azalem C...         5.274500
# 34  Hello everyone. Myself Liam Marie Biju coming ...         5.096934
# 35  Hello ma'am, this is Sapita from Chennai. Than...         5.045580
# 36  Hi myself Aaron. Thank you for providing this ...         5.071973
# 37  Hi, my name is Arnifa Slingdor, currently purs...         5.608369
# 38  Good morning. I'm Suchitta. I'm basically from...         5.186090
# 39  Hi. Greetings to everyone. I am Malaven pursui...         4.988701
# 40  Hi. Hello. I'm third. BCDS curriculum, technic...         5.500743
# 41  Heartfelt greetings to you, ma'am. My name is ...         4.987013

# %%
df.to_excel("/content/relevance_scores.xlsx")

# %%
import requests

def evaluate_grammar(text):
    """
    Evaluates the grammar of a given text using LanguageTool API.

    Args:
        text (str): The text to evaluate.

    Returns:
        float: A grammar score out of 10.
    """
    url = "https://api.languagetool.org/v2/check"
    data = {
        'text': text,
        'language': 'en-US'
    }
    response = requests.post(url, data=data)

    # Handle potential API errors
    if response.status_code != 200:
        print("Error communicating with LanguageTool API.")
        return None  # Or handle the error in a way suitable for your application

    matches = response.json().get('matches', [])
    errors = len(matches)
    total_words = len(text.split())

    # Calculate grammar score (avoiding potential division by zero)
    if total_words > 0:
        grammar_score = max(0, 10 - (errors / total_words) * 10)
    else:
        grammar_score = 10  #  Assume perfect score if no words

    return grammar_score

# Example usage
text_to_evaluate = "This is a sentence with some grammer mistakes."
score = evaluate_grammar(text_to_evaluate)

if score is not None:
    print(f"Grammar score: {score:.2f} out of 10")
# Out:
# Grammar score: 8.75 out of 10

# %%
import requests

# ... (Your existing code for evaluate_grammar function) ...

# Calculate grammar scores for each transcript
df['Grammar Score'] = df['Transcript'].apply(evaluate_grammar)

print(df[['Transcript', 'Grammar Score']])
# Out:
#                                            Transcript  Grammar Score
# 0   Hi everyone. Thank you for giving this opportu...       9.269663
# 1   Hi. Hello everyone. Myself Dhanushyar from Dha...       9.069767
# 2   Hello everyone. Myself, Bandana. I'm from Birt...       8.787879
# 3   Hello everyone. Myself, I am with Ankur Shinwa...       8.714286
# 4   Good morning sir. I am Shomindi Chandra from s...       9.586777
# 5   My name is Nimal Raj. I am from Pondicherry. I...       9.675676
# 6   Hi. Myself, Kawalakman. I'm currently pursuing...      10.000000
# 7   Hello everyone, my name is Priyanka Mandu curr...       9.642857
# 8   Good morning everyone. I thank everyone for gi...       9.325843
# 9   My name is Vibhu Shu Taman. I am currently pur...       9.200000
# 10  Hi there. My name is Artipa. I'm currently pur...       9.318182
# 11  Good morning. First of all, thank you for givi...       9.606299
# 12  Hi. Good morning. Thank you for giving me oppo...       9.340659
# 13  Hello everyone, this is Nikhil and I'm from MS...       9.600000
# 14  Good morning. I'm Vijay. Lakshmi. So I'm curre...       9.716981
# 15  Hi, I am Manikandan. I am from Thiruvana, Mala...       9.400000
# 16  Good morning myself Dubya and I am from Vendri...       9.436620
# 17  Hello. Myself, Mohammed Alyshan, and I am curr...       9.583333
# 18  I'm Sara Madame a pursuing MSC biochemistry. I...       9.937107
# 19  Good morning sir or madam. I am Shalini. I am ...       9.117647
# 20  Hi, my name is. I have completed my UG degree ...       9.740260
# 21  Good evening ma'am. First of all thank you for...       9.640288
# 22  Hi, I'm Sr. Prathana. I did my UG in food proc...       9.457364
# 23  Hello there. My name is Vikram. Currently purs...       9.803922
# 24  Thank you for giving this opportunity. My name...       9.618321
# 25  Thank you ma'am for giving me this wonderful o...       9.407407
# 26  Hello. I am Raghavi from the Department of Com...       9.513514
# 27  Sir. First of all thank you for giving me this...       9.387755
# 28  Good morning sir. My name is Aar Bhavadani. I ...       9.617834
# 29  Hello. Myself deepthika. Currently I am pursui...       9.157895
# 30  Hello. My name is Hashm Kubar. I'm currently p...       9.736842
# 31  Hello ma'am. I am Inod. I am pursuing my postg...       9.534884
# 32  Good morning sir. Thank you for giving me oppo...       9.743590
# 33  I did my UG degree in biochemistry at Azalem C...       9.333333
# 34  Hello everyone. Myself Liam Marie Biju coming ...       9.822222
# 35  Hello ma'am, this is Sapita from Chennai. Than...       9.420290
# 36  Hi myself Aaron. Thank you for providing this ...       9.728261
# 37  Hi, my name is Arnifa Slingdor, currently purs...       9.457364
# 38  Good morning. I'm Suchitta. I'm basically from...       9.483871
# 39  Hi. Greetings to everyone. I am Malaven pursui...       9.398496
# 40  Hi. Hello. I'm third. BCDS curriculum, technic...      10.000000
# 41  Heartfelt greetings to you, ma'am. My name is ...       9.500000

# %%
from transformers import pipeline

def evaluate_emotion(text):
    """
    Evaluates the emotion of a given text and returns the most probable emotion and its score.

    Args:
        text (str): The text to evaluate.

    Returns:
        tuple: A tuple containing the most probable emotion label and its score.
    """
    emotion_pipeline = pipeline('sentiment-analysis', model='j-hartmann/emotion-english-distilroberta-base')
    emotions = emotion_pipeline(text)

    if emotions:
        # Get the emotion with the highest score
        top_emotion = max(emotions, key=lambda x: x['score'])
        return top_emotion['label'], top_emotion['score']
    else:
        return None, None  # Return None if no emotions are detected

# Apply emotion evaluation and extract emotion and score into separate columns
df[['Emotion', 'Emotion Score']] = df['Transcript'].apply(lambda text: pd.Series(evaluate_emotion(text)))

print(df[['Transcript', 'Emotion', 'Emotion Score']])
# Out:
#                                            Transcript  Emotion  Emotion Score
# 0   Hi everyone. Thank you for giving this opportu...      joy       0.893323
# 1   Hi. Hello everyone. Myself Dhanushyar from Dha...      joy       0.899643
# 2   Hello everyone. Myself, Bandana. I'm from Birt...      joy       0.911965
# 3   Hello everyone. Myself, I am with Ankur Shinwa...      joy       0.894860
# 4   Good morning sir. I am Shomindi Chandra from s...      joy       0.517302
# 5   My name is Nimal Raj. I am from Pondicherry. I...      joy       0.972153
# 6   Hi. Myself, Kawalakman. I'm currently pursuing...      joy       0.984222
# 7   Hello everyone, my name is Priyanka Mandu curr...      joy       0.961263
# 8   Good morning everyone. I thank everyone for gi...      joy       0.946842
# 9   My name is Vibhu Shu Taman. I am currently pur...      joy       0.932295
# 10  Hi there. My name is Artipa. I'm currently pur...      joy       0.750904
# 11  Good morning. First of all, thank you for givi...      joy       0.928628
# 12  Hi. Good morning. Thank you for giving me oppo...      joy       0.899668
# 13  Hello everyone, this is Nikhil and I'm from MS...  neutral       0.845828
# 14  Good morning. I'm Vijay. Lakshmi. So I'm curre...      joy       0.921880
# 15  Hi, I am Manikandan. I am from Thiruvana, Mala...      joy       0.626044
# 16  Good morning myself Dubya and I am from Vendri...      joy       0.829357
# 17  Hello. Myself, Mohammed Alyshan, and I am curr...      joy       0.984335
# 18  I'm Sara Madame a pursuing MSC biochemistry. I...      joy       0.768326
# 19  Good morning sir or madam. I am Shalini. I am ...  neutral       0.521299
# 20  Hi, my name is. I have completed my UG degree ...      joy       0.937455
# 21  Good evening ma'am. First of all thank you for...      joy       0.808535
# 22  Hi, I'm Sr. Prathana. I did my UG in food proc...      joy       0.951224
# 23  Hello there. My name is Vikram. Currently purs...      joy       0.742088
# 24  Thank you for giving this opportunity. My name...      joy       0.988408
# 25  Thank you ma'am for giving me this wonderful o...      joy       0.905955
# 26  Hello. I am Raghavi from the Department of Com...      joy       0.789415
# 27  Sir. First of all thank you for giving me this...      joy       0.790917
# 28  Good morning sir. My name is Aar Bhavadani. I ...      joy       0.608979
# 29  Hello. Myself deepthika. Currently I am pursui...      joy       0.656916
# 30  Hello. My name is Hashm Kubar. I'm currently p...      joy       0.813732
# 31  Hello ma'am. I am Inod. I am pursuing my postg...      joy       0.794519
# 32  Good morning sir. Thank you for giving me oppo...      joy       0.897366
# 33  I did my UG degree in biochemistry at Azalem C...      joy       0.971525
# 34  Hello everyone. Myself Liam Marie Biju coming ...      joy       0.896372
# 35  Hello ma'am, this is Sapita from Chennai. Than...      joy       0.869885
# 36  Hi myself Aaron. Thank you for providing this ...      joy       0.893871
# 37  Hi, my name is Arnifa Slingdor, currently purs...      joy       0.843778
# 38  Good morning. I'm Suchitta. I'm basically from...      joy       0.595916
# 39  Hi. Greetings to everyone. I am Malaven pursui...      joy       0.661720
# 40  Hi. Hello. I'm third. BCDS curriculum, technic...  neutral       0.692662
# 41  Heartfelt greetings to you, ma'am. My name is ...     fear       0.618497

# %%
df.head()
# Out:
#                                File Name  \
# 0             ANUSHA S (RA2332008010011)
# 1       DHANUSHYA RAMU (RA2332016010022)
# 2         Vandhana Balasubramanian _2610
# 3  THIRUPURASUNDHARI P (RA2332016010008)
# 4      SOUMILI CHANDRA (RA2332241010163)
#
#                                           Transcript  Score  Relevance Score  \
# 0  Hi everyone. Thank you for giving this opportu...   3.29         5.406940
# 1  Hi. Hello everyone. Myself Dhanushyar from Dha...   3.37         5.156525
# 2  Hello everyone. Myself, Bandana. I'm from Birt...   3.46         5.174533
# 3  Hello everyone. Myself, I am with Ankur Shinwa...   3.68         5.018086
# 4  Good morning sir. I am Shomindi Chandra from s...   6.52         4.939860
#
#    Grammar Score                                         Emotions Emotion  \
# 0       9.269663  [{'label': 'joy', 'score': 0.8933232426643372}]     joy
# 1       9.069767  [{'label': 'joy', 'score': 0.8996433019638062}]     joy
# 2       8.787879  [{'label': 'joy', 'score': 0.9119654893875122}]     joy
# 3       8.714286  [{'label': 'joy', 'score': 0.8948600888252258}]     joy
# 4       9.586777  [{'label': 'joy', 'score': 0.5173019766807556}]     joy
#
#    Emotion Score
# 0       0.893323
# 1       0.899643
# 2       0.911965
# 3       0.894860
# 4       0.517302

# %%
df.drop(columns = ['Emotions','Score'], inplace =True)

# %%
df.head()
# Out:
#                                File Name  \
# 0             ANUSHA S (RA2332008010011)
# 1       DHANUSHYA RAMU (RA2332016010022)
# 2         Vandhana Balasubramanian _2610
# 3  THIRUPURASUNDHARI P (RA2332016010008)
# 4      SOUMILI CHANDRA (RA2332241010163)
#
#                                           Transcript  Relevance Score  \
# 0  Hi everyone. Thank you for giving this opportu...         5.406940
# 1  Hi. Hello everyone. Myself Dhanushyar from Dha...         5.156525
# 2  Hello everyone. Myself, Bandana. I'm from Birt...         5.174533
# 3  Hello everyone. Myself, I am with Ankur Shinwa...         5.018086
# 4  Good morning sir. I am Shomindi Chandra from s...         4.939860
#
#    Grammar Score Emotion  Emotion Score
# 0       9.269663     joy       0.893323
# 1       9.069767     joy       0.899643
# 2       8.787879     joy       0.911965
# 3       8.714286     joy       0.894860
# 4       9.586777     joy       0.517302

# %%
def calculate_mispronounced_words(text):  # Removed 'error_count' parameter
    """
    Calculates the number of mispronounced words in a text and returns a score out of 10.

    Args:
        text (str): The text to analyze.

    Returns:
        float: A score out of 10 representing the proportion of correctly pronounced words.
    """
    correctly_spelled_words = [
    "hello", "hi", "good", "morning", "afternoon", "evening",
    "my", "name", "is", "i'm", "am",
    "pleased", "meet", "you",
    "currently", "working", "at", "as", "a", "an",
    "position", "role", "company", "organization",
    "years", "experience", "in", "field", "industry",
    "passionate", "about", "interested",
    "skills", "include", "expertise", "proficient",
    "looking", "forward", "to", "learning", "contributing",
    "team", "collaborate", "communication", "professional",
    "etiquette", "respect", "punctuality", "integrity",
    "thank", "for", "your", "time", "consideration"
        ]



    words = text.split()
    mispronounced_count = 0  # Start with 0 mispronunciations

    for word in words:
        word = word.lower().strip('.,!?')  # Normalize word for comparison
        if word not in correctly_spelled_words:
            mispronounced_count += 1

    total_words = len(words)
    if total_words == 0:
        return 10  # Assume perfect score if no words

    # Calculate mispronunciation score
    mispronounced_score = max(0, 10 - (mispronounced_count / total_words) * 10)
    return mispronounced_score

# Apply the function to the 'Transcript' column in your DataFrame 'df'
df['Mispronunciation Score'] = df['Transcript'].apply(calculate_mispronounced_words)

print(df[['Transcript', 'Mispronunciation Score']])
# Out:
#                                            Transcript  Mispronunciation Score
# 0   Hi everyone. Thank you for giving this opportu...                2.696629
# 1   Hi. Hello everyone. Myself Dhanushyar from Dha...                2.906977
# 2   Hello everyone. Myself, Bandana. I'm from Birt...                3.030303
# 3   Hello everyone. Myself, I am with Ankur Shinwa...                2.142857
# 4   Good morning sir. I am Shomindi Chandra from s...                2.396694
# 5   My name is Nimal Raj. I am from Pondicherry. I...                3.351351
# 6   Hi. Myself, Kawalakman. I'm currently pursuing...                2.241379
# 7   Hello everyone, my name is Priyanka Mandu curr...                3.333333
# 8   Good morning everyone. I thank everyone for gi...                3.258427
# 9   My name is Vibhu Shu Taman. I am currently pur...                3.600000
# 10  Hi there. My name is Artipa. I'm currently pur...                2.727273
# 11  Good morning. First of all, thank you for givi...                3.543307
# 12  Hi. Good morning. Thank you for giving me oppo...                3.736264
# 13  Hello everyone, this is Nikhil and I'm from MS...                1.800000
# 14  Good morning. I'm Vijay. Lakshmi. So I'm curre...                2.830189
# 15  Hi, I am Manikandan. I am from Thiruvana, Mala...                2.400000
# 16  Good morning myself Dubya and I am from Vendri...                2.816901
# 17  Hello. Myself, Mohammed Alyshan, and I am curr...                2.916667
# 18  I'm Sara Madame a pursuing MSC biochemistry. I...                1.949686
# 19  Good morning sir or madam. I am Shalini. I am ...                3.161765
# 20  Hi, my name is. I have completed my UG degree ...                4.285714
# 21  Good evening ma'am. First of all thank you for...                3.021583
# 22  Hi, I'm Sr. Prathana. I did my UG in food proc...                2.558140
# 23  Hello there. My name is Vikram. Currently purs...                3.137255
# 24  Thank you for giving this opportunity. My name...                2.748092
# 25  Thank you ma'am for giving me this wonderful o...                2.888889
# 26  Hello. I am Raghavi from the Department of Com...                1.567568
# 27  Sir. First of all thank you for giving me this...                2.857143
# 28  Good morning sir. My name is Aar Bhavadani. I ...                2.356688
# 29  Hello. Myself deepthika. Currently I am pursui...                3.368421
# 30  Hello. My name is Hashm Kubar. I'm currently p...                3.157895
# 31  Hello ma'am. I am Inod. I am pursuing my postg...                2.441860
# 32  Good morning sir. Thank you for giving me oppo...                3.717949
# 33  I did my UG degree in biochemistry at Azalem C...                3.466667
# 34  Hello everyone. Myself Liam Marie Biju coming ...                3.155556
# 35  Hello ma'am, this is Sapita from Chennai. Than...                2.898551
# 36  Hi myself Aaron. Thank you for providing this ...                2.065217
# 37  Hi, my name is Arnifa Slingdor, currently purs...                2.325581
# 38  Good morning. I'm Suchitta. I'm basically from...                2.774194
# 39  Hi. Greetings to everyone. I am Malaven pursui...                2.255639
# 40  Hi. Hello. I'm third. BCDS curriculum, technic...                3.666667
# 41  Heartfelt greetings to you, ma'am. My name is ...                3.071429

# %%
df.head()
# Out:
#                                File Name  \
# 0             ANUSHA S (RA2332008010011)
# 1       DHANUSHYA RAMU (RA2332016010022)
# 2         Vandhana Balasubramanian _2610
# 3  THIRUPURASUNDHARI P (RA2332016010008)
# 4      SOUMILI CHANDRA (RA2332241010163)
#
#                                           Transcript  Relevance Score  \
# 0  Hi everyone. Thank you for giving this opportu...         5.406940
# 1  Hi. Hello everyone. Myself Dhanushyar from Dha...         5.156525
# 2  Hello everyone. Myself, Bandana. I'm from Birt...         5.174533
# 3  Hello everyone. Myself, I am with Ankur Shinwa...         5.018086
# 4  Good morning sir. I am Shomindi Chandra from s...         4.939860
#
#    Grammar Score Emotion  Emotion Score  Mispronunciation Score
# 0       9.269663     joy       0.893323                2.696629
# 1       9.069767     joy       0.899643                2.906977
# 2       8.787879     joy       0.911965                3.030303
# 3       8.714286     joy       0.894860                2.142857
# 4       9.586777     joy       0.517302                2.396694

# %%
def calculate_speech_rate(audio_file, text):
    duration = librosa.get_duration(filename=audio_file)
    words = text.split()
    num_words = len(words)
    words_per_minute = (num_words / duration) * 60
    min_wpm = 100  # Minimum words per minute
    max_wpm = 160  # Maximum words per minute

    if words_per_minute < min_wpm:
        speech_rate_score = max(0, 10 - ((min_wpm - words_per_minute) / min_wpm) * 10)
    elif words_per_minute > max_wpm:
        speech_rate_score = max(0, 10 - ((words_per_minute - max_wpm) / max_wpm) * 10)
    else:
        speech_rate_score = 10  # Perfect score if within acceptable range

    return speech_rate_score

# %%
df['Speech_Rate_Score'] = df['Transcript'].apply(calculate_mispronounced_words)

# %%
df.head()
# Out:
#                                File Name  \
# 0             ANUSHA S (RA2332008010011)
# 1       DHANUSHYA RAMU (RA2332016010022)
# 2         Vandhana Balasubramanian _2610
# 3  THIRUPURASUNDHARI P (RA2332016010008)
# 4      SOUMILI CHANDRA (RA2332241010163)
#
#                                           Transcript  Relevance Score  \
# 0  Hi everyone. Thank you for giving this opportu...         5.406940
# 1  Hi. Hello everyone. Myself Dhanushyar from Dha...         5.156525
# 2  Hello everyone. Myself, Bandana. I'm from Birt...         5.174533
# 3  Hello everyone. Myself, I am with Ankur Shinwa...         5.018086
# 4  Good morning sir. I am Shomindi Chandra from s...         4.939860
#
#    Grammar Score Emotion  Emotion Score  Mispronunciation Score  \
# 0       9.269663     joy       0.893323                2.696629
# 1       9.069767     joy       0.899643                2.906977
# 2       8.787879     joy       0.911965                3.030303
# 3       8.714286     joy       0.894860                2.142857
# 4       9.586777     joy       0.517302                2.396694
#
#    Speech_Rate_Score
# 0           2.696629
# 1           2.906977
# 2           3.030303
# 3           2.142857
# 4           2.396694

# %%
# Apply the lambda function to scale 'Emotion Score'
df['Emotion Score'] = df['Emotion Score'].apply(lambda score: score * 10)

df.head()
# Out:
#                                File Name  \
# 0             ANUSHA S (RA2332008010011)
# 1       DHANUSHYA RAMU (RA2332016010022)
# 2         Vandhana Balasubramanian _2610
# 3  THIRUPURASUNDHARI P (RA2332016010008)
# 4      SOUMILI CHANDRA (RA2332241010163)
#
#                                           Transcript  Relevance Score  \
# 0  Hi everyone. Thank you for giving this opportu...         5.406940
# 1  Hi. Hello everyone. Myself Dhanushyar from Dha...         5.156525
# 2  Hello everyone. Myself, Bandana. I'm from Birt...         5.174533
# 3  Hello everyone. Myself, I am with Ankur Shinwa...         5.018086
# 4  Good morning sir. I am Shomindi Chandra from s...         4.939860
#
#    Grammar Score Emotion  Emotion Score  Mispronunciation Score  \
# 0       9.269663     joy       8.933232                2.696629
# 1       9.069767     joy       8.996433                2.906977
# 2       8.787879     joy       9.119655                3.030303
# 3       8.714286     joy       8.948601                2.142857
# 4       9.586777     joy       5.173020                2.396694
#
#    Speech_Rate_Score
# 0           2.696629
# 1           2.906977
# 2           3.030303
# 3           2.142857
# 4           2.396694

# %%
def detect_pauses(audio_file, min_silence_duration=1.0, top_db=20):
    y, sr = librosa.load(audio_file)
    non_silent_intervals = librosa.effects.split(y, top_db=top_db)
    pauses = []
    for i in range(1, len(non_silent_intervals)):
        start = non_silent_intervals[i-1][1]
        end = non_silent_intervals[i][0]
        pause_duration = (end - start) / sr
        if pause_duration >= min_silence_duration:
            pauses.append(pause_duration)
    num_pauses = max(0, len(pauses) - 2)
    max_pauses = 10
    if num_pauses > max_pauses:
        pause_score = max(0, 10 - ((num_pauses - max_pauses) / max_pauses) * 10)
    else:
        pause_score = 10

    return pause_score

# %%
df['detect_pausein_speech_Score'] = df['Transcript'].apply(calculate_mispronounced_words)

# %%
df.head()
# Out:
#                                File Name  \
# 0             ANUSHA S (RA2332008010011)
# 1       DHANUSHYA RAMU (RA2332016010022)
# 2         Vandhana Balasubramanian _2610
# 3  THIRUPURASUNDHARI P (RA2332016010008)
# 4      SOUMILI CHANDRA (RA2332241010163)
#
#                                           Transcript  Relevance Score  \
# 0  Hi everyone. Thank you for giving this opportu...         5.406940
# 1  Hi. Hello everyone. Myself Dhanushyar from Dha...         5.156525
# 2  Hello everyone. Myself, Bandana. I'm from Birt...         5.174533
# 3  Hello everyone. Myself, I am with Ankur Shinwa...         5.018086
# 4  Good morning sir. I am Shomindi Chandra from s...         4.939860
#
#    Grammar Score Emotion  Emotion Score  Mispronunciation Score  \
# 0       9.269663     joy       8.933232                2.696629
# 1       9.069767     joy       8.996433                2.906977
# 2       8.787879     joy       9.119655                3.030303
# 3       8.714286     joy       8.948601                2.142857
# 4       9.586777     joy       5.173020                2.396694
#
#    Speech_Rate_Score  detect_pausein_speech_Score
# 0           2.696629                     2.696629
# 1           2.906977                     2.906977
# 2           3.030303                     3.030303
# 3           2.142857                     2.142857
# 4           2.396694                     2.396694

# %%
# prompt: Using dataframe df: give me the overall score ciolumn by adding all the scores from each cols and scale it to 10

# Create a new column 'Overall Score' by summing relevant scores
df['Overall Score'] = df['Relevance Score'] + df['Grammar Score'] + df['Emotion Score'] + df['Mispronunciation Score'] + df['Speech_Rate_Score'] + df['detect_pausein_speech_Score']

# Scale the 'Overall Score' to a maximum of 10
max_score = df['Overall Score'].max()
df['Overall Score'] = (df['Overall Score'] / max_score) * 10

# Display the DataFrame with the new 'Overall Score' column
df.head()
# Out:
#                                File Name  \
# 0             ANUSHA S (RA2332008010011)
# 1       DHANUSHYA RAMU (RA2332016010022)
# 2         Vandhana Balasubramanian _2610
# 3  THIRUPURASUNDHARI P (RA2332016010008)
# 4      SOUMILI CHANDRA (RA2332241010163)
#
#                                           Transcript  Relevance Score  \
# 0  Hi everyone. Thank you for giving this opportu...         5.406940
# 1  Hi. Hello everyone. Myself Dhanushyar from Dha...         5.156525
# 2  Hello everyone. Myself, Bandana. I'm from Birt...         5.174533
# 3  Hello everyone. Myself, I am with Ankur Shinwa...         5.018086
# 4  Good morning sir. I am Shomindi Chandra from s...         4.939860
#
#    Grammar Score Emotion  Emotion Score  Mispronunciation Score  \
# 0       9.269663     joy       8.933232                2.696629
# 1       9.069767     joy       8.996433                2.906977
# 2       8.787879     joy       9.119655                3.030303
# 3       8.714286     joy       8.948601                2.142857
# 4       9.586777     joy       5.173020                2.396694
#
#    Speech_Rate_Score  detect_pausein_speech_Score  Overall Score
# 0           2.696629                     2.696629       8.512725
# 1           2.906977                     2.906977       8.578231
# 2           3.030303                     3.030303       8.639813
# 3           2.142857                     2.142857       7.817151
# 4           2.396694                     2.396694       7.221039

# %%
df.to_excel("/content/Overall_scores.xlsx")
